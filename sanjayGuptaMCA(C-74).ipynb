# %% [markdown]
# Name- Sanjay Gupta
# Course-MCA(C)
# Student_id=23391100

# %%
Electricty_bill=0.0
Electricty_bill=float(Electricty_bill)

unit=float(input("Enter your uses unit_bill:="))
if unit<=100:
    electricity_charge=100
    print("There is no charges  on electricty_bill",Electricty_bill)
    
elif unit>100 and unit<=200:
    
    Electricty_bill=(unit-100)*5+100
    
    
    print("total Bill:=",Electricty_bill)
    
elif unit>=200 :
    
    Electricty_bill=600+(unit-200)*10
    
    
    print("total Bill:=",Electricty_bill)
    
else:
    print("calculate properly ")

# Q2 ) Write a program to display “Welcome” if the number entered is a multiple of 5. 

number=int(input("enter your number="))
if number%5==0:
    print("welconme")
else:
    print("number is not divisible ") 

# Q3 ) Write a Python program to check if the number is divisible by both 5 and 7 or not.
num = int(input("Enter number="))
    
if num%5 == 0 and num%7 == 0:
        print("Number is divisible  by both  5 and 7 \n")
elif num%5 == 0 or num%7 == 0:
        print("Number is divisible atleast one 5 or 7")

else:
    print("number is not divisible")

# Q4 ) Write a Python program to display the last digit of a number and then check whether it is divisible by 3 or not. 
number=int(input("enter Number :"))
rem=number%10
print("last digit of a number is ",rem)
if  (rem %3==0):
    print("The last digit is Divisible ")
else:
    print("Not  Divisible")
# Q5 ) Write a Python program to reverse a number

num = int(input("Enter a  number:"))

print(str(num)[::-1])



# Q6 ) Write a Python program to find the sum of digits of a number 
n=int(input( "enter number :" ))
sum = 0;
while n != 0:  
    sum = sum + n % 10;
    n = n / 10;
print ("sum of digit",sum)

# Q7 ) Write a Python program to check whether a number is prime or not 

primeOrNot = int(input("Enter a number: "))

if primeOrNot<2 :
    print("it is  not a prime number")
    exit()
flag = 1
for i in range(2, primeOrNot//2):
    if primeOrNot%i == 0 :
        flag = 0 
        break
        
if flag:
    print(primeOrNot, "is a prime number")
else:
    print(primeOrNot, "is not a prime number")
